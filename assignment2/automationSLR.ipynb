# %%
import pydot
from IPython.display import Image

# %%
auto = pydot.Dot(graph_type = 'digraph')

I0 = pydot.Node(u'I\u2080' )
auto.add_node(I0)

I1 = pydot.Node(u'I\u2081' )
auto.add_node(I1)
edge = pydot.Edge(I0, I1)
edge.set_label("id")
auto.add_edge(edge)

I2 = pydot.Node(u'I\u2082' )
auto.add_node(I2)
edge = pydot.Edge(I0, I2)
edge.set_label("S")
auto.add_edge(edge)

I3 = pydot.Node(u'I\u2083' )
auto.add_node(I3)
edge = pydot.Edge(I1, I3)
edge.set_label(" [")
auto.add_edge(edge)

I4 = pydot.Node(u'I\u2084',color='blue' )
auto.add_node(I4)
edge = pydot.Edge(I3, I4)
edge.set_label(" (")
auto.add_edge(edge)

I5 = pydot.Node(u'I\u2085' )
auto.add_node(I5)
edge = pydot.Edge(I3, I5)
edge.set_label(" id")
auto.add_edge(edge)

I6 = pydot.Node(u'I\u2086' )
auto.add_node(I6)
edge = pydot.Edge(I3, I6)
edge.set_label(" E")
auto.add_edge(edge)

I7 = pydot.Node(u'I\u2087' )
auto.add_node(I7)
edge = pydot.Edge(I6, I7)
edge.set_label(" ]")
auto.add_edge(edge)

I8 = pydot.Node(u'I\u2088' )
auto.add_node(I8)
edge = pydot.Edge(I6, I8)
edge.set_label(" +")
auto.add_edge(edge)

I9 = pydot.Node(u'I\u2089' )
auto.add_node(I9)
edge = pydot.Edge(I3, I9)
edge.set_label(" T")
auto.add_edge(edge)
edge = pydot.Edge(I4, I9)
edge.set_label(" T")
auto.add_edge(edge)

I10 = pydot.Node(u'I\u2081\u2080' )
auto.add_node(I10)
edge = pydot.Edge(I9, I10)
edge.set_label(" *")
auto.add_edge(edge)

I15 = pydot.Node(u'I\u2081\u2085' )
auto.add_node(I15)
edge = pydot.Edge(I7, I15)
edge.set_label(" :=")
auto.add_edge(edge)

I11 = pydot.Node(u'I\u2081\u2081' )
auto.add_node(I11)
edge = pydot.Edge(I3, I11)
edge.set_label(" F")
auto.add_edge(edge)

I12 = pydot.Node(u'I\u2081\u2082' )
auto.add_node(I12)
edge = pydot.Edge(I4, I12)
edge.set_label(" E")
auto.add_edge(edge)

I13 = pydot.Node(u'I\u2081\u2083' )
auto.add_node(I13)
edge = pydot.Edge(I12, I13)
edge.set_label(" )")
auto.add_edge(edge)

I14 = pydot.Node(u'I\u2081\u2084' )
auto.add_node(I14)
edge = pydot.Edge(I8, I14)
edge.set_label(" T")
auto.add_edge(edge)

I16 = pydot.Node(u'I\u2081\u2086' )
auto.add_node(I16)
edge = pydot.Edge(I10, I16)
edge.set_label(" F")
auto.add_edge(edge)

I17 = pydot.Node(u'I\u2081\u2087' )
auto.add_node(I17)
edge = pydot.Edge(I15, I17)
edge.set_label(" E")
auto.add_edge(edge)

edge = pydot.Edge(I4, I4,color='green')
edge.set_label(" (")
auto.add_edge(edge)

edge = pydot.Edge(I4, I5)
edge.set_label(" id")
auto.add_edge(edge)

edge = pydot.Edge(I12, I8)
edge.set_label(" +")
auto.add_edge(edge)

edge = pydot.Edge(I4, I11)
edge.set_label(" F")
auto.add_edge(edge)

edge = pydot.Edge(I14, I10)
edge.set_label(" *")
auto.add_edge(edge)

edge = pydot.Edge(I8, I11)
edge.set_label(" F")
auto.add_edge(edge)

edge = pydot.Edge(I8, I4)
edge.set_label(" (")
auto.add_edge(edge)

edge = pydot.Edge(I8, I5)
edge.set_label(" id")
auto.add_edge(edge)

edge = pydot.Edge(I9, I10)
edge.set_label(" *")
auto.add_edge(edge)

edge = pydot.Edge(I10, I4)
edge.set_label(" (")
auto.add_edge(edge)

edge = pydot.Edge(I15, I5)
edge.set_label(" id")
auto.add_edge(edge)

edge = pydot.Edge(I15, I9)
edge.set_label(" T")
auto.add_edge(edge)

edge = pydot.Edge(I15, I11)
edge.set_label(" F")
auto.add_edge(edge)

edge = pydot.Edge(I15, I4)
edge.set_label(" (")
auto.add_edge(edge)

edge = pydot.Edge(I17, I8)
edge.set_label(" +")
auto.add_edge(edge)

edge = pydot.Edge(I10, I5)
edge.set_label(" id")
auto.add_edge(edge)

# %%
auto.write_png('autoSLR.png')
Image(filename='autoSLR.png')
